# %% [markdown]
# # Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Importing the dataset

# %%
dataset = pd.read_csv('50_Startups.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1:].values.flatten()

dataset.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_6cfa3128_adb7_11e7_b268_d8d385958556row0_col0 {
#             background-color:  #023858;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row0_col1 {
#             background-color:  #2c89bd;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row0_col2 {
#             background-color:  #023858;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row0_col4 {
#             background-color:  #023858;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row1_col0 {
#             background-color:  #023c5f;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row1_col1 {
#             background-color:  #056dac;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row1_col2 {
#             background-color:  #034871;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row1_col4 {
#             background-color:  #023858;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row2_col0 {
#             background-color:  #034b76;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row2_col1 {
#             background-color:  #a4bcda;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row2_col2 {
#             background-color:  #045b8f;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row2_col4 {
#             background-color:  #02395a;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row3_col0 {
#             background-color:  #045a8d;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row3_col1 {
#             background-color:  #6da6cd;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row3_col2 {
#             background-color:  #05659f;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row3_col4 {
#             background-color:  #03466e;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row4_col0 {
#             background-color:  #045c90;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row4_col1 {
#             background-color:  #bdc8e1;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row4_col2 {
#             background-color:  #056ba9;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row4_col4 {
#             background-color:  #045e93;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row5_col0 {
#             background-color:  #0567a2;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row5_col1 {
#             background-color:  #a8bedc;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row5_col2 {
#             background-color:  #056dab;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row5_col4 {
#             background-color:  #0567a1;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row6_col0 {
#             background-color:  #04649e;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row6_col1 {
#             background-color:  #0d75b3;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row6_col2 {
#             background-color:  #c9cee4;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row6_col4 {
#             background-color:  #0568a3;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row7_col0 {
#             background-color:  #0569a5;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row7_col1 {
#             background-color:  #1278b4;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row7_col2 {
#             background-color:  #1e80b8;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row7_col4 {
#             background-color:  #0568a3;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row8_col0 {
#             background-color:  #0d75b3;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row8_col1 {
#             background-color:  #0872b1;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row8_col2 {
#             background-color:  #2786bb;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row8_col4 {
#             background-color:  #056ba9;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row9_col0 {
#             background-color:  #0771b1;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row9_col1 {
#             background-color:  #8eb3d5;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row9_col2 {
#             background-color:  #2d8abd;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row9_col4 {
#             background-color:  #056ead;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row10_col0 {
#             background-color:  #3b92c1;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row10_col1 {
#             background-color:  #88b1d4;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row10_col2 {
#             background-color:  #79abd0;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row10_col4 {
#             background-color:  #0872b1;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row11_col0 {
#             background-color:  #3f93c2;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row11_col1 {
#             background-color:  #bdc8e1;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row11_col2 {
#             background-color:  #65a3cb;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row11_col4 {
#             background-color:  #0d75b3;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row12_col0 {
#             background-color:  #529bc7;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row12_col1 {
#             background-color:  #4c99c5;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row12_col2 {
#             background-color:  #65a3cb;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row12_col4 {
#             background-color:  #1379b5;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row13_col0 {
#             background-color:  #589ec8;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row13_col1 {
#             background-color:  #2f8bbe;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row13_col2 {
#             background-color:  #62a2cb;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row13_col4 {
#             background-color:  #2383ba;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row14_col0 {
#             background-color:  #0f76b3;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row14_col1 {
#             background-color:  #0567a1;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row14_col2 {
#             background-color:  #5ea0ca;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row14_col4 {
#             background-color:  #2786bb;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row15_col0 {
#             background-color:  #1b7eb7;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row15_col1 {
#             background-color:  #5ea0ca;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row15_col2 {
#             background-color:  #589ec8;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row15_col4 {
#             background-color:  #2c89bd;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row16_col0 {
#             background-color:  #80aed2;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row16_col1 {
#             background-color:  #62a2cb;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row16_col2 {
#             background-color:  #569dc8;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row16_col4 {
#             background-color:  #348ebf;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row17_col0 {
#             background-color:  #509ac6;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row17_col1 {
#             background-color:  #1379b5;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row17_col2 {
#             background-color:  #4295c3;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row17_col4 {
#             background-color:  #3790c0;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row18_col0 {
#             background-color:  #589ec8;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row18_col1 {
#             background-color:  #7dacd1;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row18_col2 {
#             background-color:  #358fc0;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d385958556row18_col4 {
#             background-color:  #3b92c1;
#         }    #T_6cfa3128_adb7_11e7_b268_d8d

# %% [markdown]
# # Encoding categorical data

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder = LabelEncoder()
X[:, 3] = labelencoder.fit_transform(X[:, 3])
onehotencoder = OneHotEncoder(categorical_features = [3])
X = onehotencoder.fit_transform(X).toarray()

# %% [markdown]
# # Avoiding the Dummy Variable Trap

# %%
X = X[:, 1:]

# %% [markdown]
# # Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# # Feature Scaling

# %%
# %%capture
# unnecessary
"""
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train)
"""

# %% [markdown]
# # Fitting Multiple Linear Regression to the Training set

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# # Predicting the Test set results

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# # Building the optimal model using Backward elimination

# %%
import statsmodels.formula.api as sm
X = np.append(np.ones((len(X), 1)), X, 1)
X_opt = X[:, [0, 1, 2, 3, 4, 5]]
regressor_ols = sm.OLS(endog = y, exog = X_opt).fit()
regressor_ols.summary()
X_opt = X[:, [0, 1, 3, 4, 5]]
regressor_ols = sm.OLS(endog = y, exog = X_opt).fit()
regressor_ols.summary()
X_opt = X[:, [0, 3, 4, 5]]
regressor_ols = sm.OLS(endog = y, exog = X_opt).fit()
regressor_ols.summary()
X_opt = X[:, [0, 3, 5]]
regressor_ols = sm.OLS(endog = y, exog = X_opt).fit()
regressor_ols.summary()
X_opt = X[:, [0, 3]]
regressor_ols = sm.OLS(endog = y, exog = X_opt).fit()
regressor_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     849.8
# Date:                Tue, 10 Oct 2017   Prob (F-statistic):           3.50e-32
# Time:                        14:38:02   Log-Likelihood:                -527.44
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      48   BIC:                             1063.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.903e+04   2537.897     19.320      0.000    4.39e+04    5.41e+04
# x1             0.8543      0.029     29.151      0.000       0.795       0.913
# ==============================================================================
# Omnibus:                       13.727   Durbin-Watson:                   1.116
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               18.536
# Skew:                          -0.911   Prob(JB):                     9.44e-05
# Kurtosis:                       5.361   Cond. No.                     1.65e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.65e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
